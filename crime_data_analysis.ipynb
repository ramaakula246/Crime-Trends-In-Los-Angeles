# %% [markdown]
#                                                           Crime Trends In Los Angeles (2020-Present)

# %% [markdown]
#                                                                IMPORTING REQUIRED LIBRARIES

# %%
#"Crime Trends in Los Angeles (2020–Present): A Data-Driven Analysis and Visualization"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#                                                                 LOADING DATASET AND DESCRIBE

# %%
df=pd.read_csv("/content/Crime_Data_from_2020_to_Present.csv")
df.describe()
# Out:
#               DR_NO      TIME OCC          AREA   Rpt Dist No      Part 1-2  \
# count  1.005198e+06  1.005198e+06  1.005198e+06  1.005198e+06  1.005198e+06
# mean   2.202277e+08  1.339911e+03  1.069098e+01  1.115556e+03  1.400283e+00
# std    1.320282e+07  6.510531e+02  6.110385e+00  6.111733e+02  4.899559e-01
# min    8.170000e+02  1.000000e+00  1.000000e+00  1.010000e+02  1.000000e+00
# 25%    2.106169e+08  9.000000e+02  5.000000e+00  5.870000e+02  1.000000e+00
# 50%    2.209160e+08  1.420000e+03  1.100000e+01  1.139000e+03  1.000000e+00
# 75%    2.311105e+08  1.900000e+03  1.600000e+01  1.613000e+03  2.000000e+00
# max    2.521041e+08  2.359000e+03  2.100000e+01  2.199000e+03  2.000000e+00
#
#              Crm Cd      Vict Age     Premis Cd  Weapon Used Cd      Crm Cd 1  \
# count  1.005198e+06  1.005198e+06  1.005182e+06   327280.000000  1.005187e+06
# mean   5.001458e+02  2.891253e+01  3.056189e+02      363.953651  4.999063e+02
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005198 entries, 0 to 1005197
# Data columns (total 28 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   DR_NO           1005198 non-null  int64
#  1   Date Rptd       1005198 non-null  object
#  2   DATE OCC        1005198 non-null  object
#  3   TIME OCC        1005198 non-null  int64
#  4   AREA            1005198 non-null  int64
#  5   AREA NAME       1005198 non-null  object
#  6   Rpt Dist No     1005198 non-null  int64
#  7   Part 1-2        1005198 non-null  int64
#  8   Crm Cd          1005198 non-null  int64
#  9   Crm Cd Desc     1005198 non-null  object
#  10  Mocodes         853438 non-null   object
#  11  Vict Age        1005198 non-null  int64
#  12  Vict Sex        860416 non-null   object
#  13  Vict Descent    860404 non-null   object
#  14  Premis Cd       1005182 non-null  float64
#  15  Premis Desc     1004610 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  200412582  09/09/2020 12:00:00 AM  09/09/2020 12:00:00 AM       630     4
#
#     AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Wilshire          784         1     510
# 1     Central          182         1     330
# 2   Southwest          356         1     480
# 3    Van Nuys          964         1     343
# 4  Hollenbeck          413         1     510
#
#                                 Crm Cd Desc  ... Status   Status Desc  \
# 0                          VEHICLE - STOLEN  ...     AA  Adult Arrest
# 1                     BURGLARY FROM VEHICLE  ...     IC   Invest Cont
# ...

# %%
df.tail()
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 1005193  250304214  02/23/2025 12:00:00 AM  02/21/2025 12:00:00 AM      1530
# 1005194  250304203  02/20/2025 12:00:00 AM  02/13/2025 12:00:00 AM      2100
# 1005195  250504051  01/14/2025 12:00:00 AM  01/14/2025 12:00:00 AM      1250
# 1005196  251604136  02/27/2025 12:00:00 AM  02/27/2025 12:00:00 AM      1550
# 1005197  251904210  03/25/2025 12:00:00 AM  03/25/2025 12:00:00 AM      1235
#
#          AREA  AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 1005193     3  Southwest          358         1     510
# 1005194     3  Southwest          325         1     522
# 1005195     5     Harbor          509         1     210
# 1005196    16   Foothill         1664         1     510
# 1005197    19    Mission         1944         2     850
#
#                                                Crm Cd Desc  ... Status  \
# 1005193                                   VEHICLE - STOLEN  ...     IC
# ...

# %%
# Clean column name first
df.columns = df.columns.str.strip().str.upper().str.replace(' ', '_')

# Convert DATE_OCC to datetime with correct format
df['DATE_OCC'] = pd.to_datetime(df['DATE_OCC'], format='%m/%d/%Y %I:%M:%S %p', errors='coerce')

# Extract Year
df['YEAR'] = df['DATE_OCC'].dt.year

# %%
# Dropping duplicates
df = df.drop_duplicates()

# Standardizing column names
df.columns = df.columns.str.strip().str.upper().str.replace(' ', '_')

# Changing data types
df['DATE_OCC'] = pd.to_datetime(df['DATE_OCC'])

# %%
# Checking missing values
print(df.isnull().sum())

# Dropping rows with missing values in important columns
df_clean = df.dropna(subset=['DATE_OCC', 'AREA_NAME'])
# Replacing missing values correctly
df['WEAPON_DESC'] = df['WEAPON_DESC'].fillna('UNKNOWN')
df['VICT_SEX'] = df['VICT_SEX'].fillna('UNKNOWN')
df['VICT_DESCENT'] = df['VICT_DESCENT'].fillna('UNKNOWN')
df['PREMIS_DESC'] = df['PREMIS_DESC'].fillna('UNKNOWN')
df['CROSS_STREET'] = df['CROSS_STREET'].fillna('NOT AVAILABLE')
# Out:
# DR_NO                   0
# DATE_RPTD               0
# DATE_OCC                0
# TIME_OCC                0
# AREA                    0
# AREA_NAME               0
# RPT_DIST_NO             0
# PART_1-2                0
# CRM_CD                  0
# CRM_CD_DESC             0
# MOCODES            151760
# VICT_AGE                0
# VICT_SEX           144782
# VICT_DESCENT       144794
# PREMIS_CD              16
# PREMIS_DESC           588
# WEAPON_USED_CD     677918
# WEAPON_DESC        677918
# STATUS                  1
# STATUS_DESC             0
# CRM_CD_1               11
# CRM_CD_2           936039
# CRM_CD_3          1002884
# CRM_CD_4          1005134
# LOCATION                0
# CROSS_STREET       850955
# LAT                     0
# LON                     0
# YEAR                    0
# dtype: int64

# %%
 #Data Visualization
#1. Principles of Visualization
#Use visualizations to show:
#Frequency of crimes
#Trends over time
#Crime locations
#2. Matplotlib Plots
# Crime count per year
df['YEAR'].value_counts().sort_index().plot(kind='bar', figsize=(10, 5), color='skyblue', edgecolor='black')
plt.title("Crime Count Per Year")
plt.xlabel("Year")
plt.ylabel("Number of Crimes")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#3. Advanced Visualization with Seaborn
# Crime distribution by area
plt.figure(figsize=(12, 6))
sns.countplot(y='AREA_NAME', data=df, order=df['AREA_NAME'].value_counts().index)
plt.title('Crime Count by Area')
plt.show()

# Time trend of crimes
df['Month'] = pd.to_datetime(df['DATE_OCC']).dt.to_period('M')
monthly_crime = df['Month'].value_counts().sort_index()

monthly_crime.plot(kind='line', figsize=(14,6))
plt.title("Monthly Crime Trend")
plt.ylabel("Number of Crimes")
plt.show()

# %%
#4. Customizing Visualizations
import seaborn as sns
import matplotlib.pyplot as plt

# Set seaborn style
sns.set_style("whitegrid")

# Create histogram for YEAR
plt.figure(figsize=(10, 6))
sns.histplot(df['YEAR'], bins=10, kde=True, color='skyblue')

# Labels and title
plt.title("Crime Frequency by Year")
plt.xlabel("Year")
plt.ylabel("Crime Count")
plt.tight_layout()
plt.show()

# %%
#Exploratory Data Analysis (EDA)
#1. Understanding EDA
#EDA involves identifying patterns, trends, anomalies, and summary insights before modeling.
#2. Summary Statistics
print(df.describe(include='all'))
# Out:
#                DR_NO               DATE_RPTD                       DATE_OCC  \
# count   1.005198e+06                 1005198                        1005198
# unique           NaN                    1906                            NaN
# top              NaN  02/02/2023 12:00:00 AM                            NaN
# freq             NaN                     929                            NaN
# mean    2.202277e+08                     NaN  2022-05-13 22:42:44.629057792
# min     8.170000e+02                     NaN            2020-01-01 00:00:00
# 25%     2.106169e+08                     NaN            2021-04-06 00:00:00
# 50%     2.209160e+08                     NaN            2022-05-26 00:00:00
# 75%     2.311105e+08                     NaN            2023-06-22 00:00:00
# max     2.521041e+08                     NaN            2025-03-27 00:00:00
# std     1.320282e+07                     NaN                            NaN
#
# ...

# %%
#3. Correlation & Covariance
correlation_matrix = df.corr(numeric_only=True)
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
#4. Outlier Detection
import seaborn as sns
import matplotlib.pyplot as plt
# Boxplot for detecting outliers in victim age
plt.figure(figsize=(10, 5))
sns.boxplot(x='VICT_AGE', data=df, color='mediumseagreen')
plt.title("Outlier Detection: Victim Age")
plt.xlabel("Victim Age")
plt.tight_layout()
plt.show()

# %%
print(df.columns)
# Out:
# Index(['DR_NO', 'DATE_RPTD', 'DATE_OCC', 'TIME_OCC', 'AREA', 'AREA_NAME',
#        'RPT_DIST_NO', 'PART_1-2', 'CRM_CD', 'CRM_CD_DESC', 'MOCODES',
#        'VICT_AGE', 'VICT_SEX', 'VICT_DESCENT', 'PREMIS_CD', 'PREMIS_DESC',
#        'WEAPON_USED_CD', 'WEAPON_DESC', 'STATUS', 'STATUS_DESC', 'CRM_CD_1',
#        'CRM_CD_2', 'CRM_CD_3', 'CRM_CD_4', 'LOCATION', 'CROSS_STREET', 'LAT',
#        'LON', 'YEAR', 'Month'],
#       dtype='object')

# %%
# Strip leading/trailing spaces from column names (common issue)
df.columns = df.columns.str.strip()

# Display all column names
print(df.columns.tolist())
# Out:
# ['DR_NO', 'DATE_RPTD', 'DATE_OCC', 'TIME_OCC', 'AREA', 'AREA_NAME', 'RPT_DIST_NO', 'PART_1-2', 'CRM_CD', 'CRM_CD_DESC', 'MOCODES', 'VICT_AGE', 'VICT_SEX', 'VICT_DESCENT', 'PREMIS_CD', 'PREMIS_DESC', 'WEAPON_USED_CD', 'WEAPON_DESC', 'STATUS', 'STATUS_DESC', 'CRM_CD_1', 'CRM_CD_2', 'CRM_CD_3', 'CRM_CD_4', 'LOCATION', 'CROSS_STREET', 'LAT', 'LON', 'YEAR', 'Month']

# %%
df.columns = df.columns.str.strip()
print(df.columns.tolist())
# Out:
# ['DR_NO', 'DATE_RPTD', 'DATE_OCC', 'TIME_OCC', 'AREA', 'AREA_NAME', 'RPT_DIST_NO', 'PART_1-2', 'CRM_CD', 'CRM_CD_DESC', 'MOCODES', 'VICT_AGE', 'VICT_SEX', 'VICT_DESCENT', 'PREMIS_CD', 'PREMIS_DESC', 'WEAPON_USED_CD', 'WEAPON_DESC', 'STATUS', 'STATUS_DESC', 'CRM_CD_1', 'CRM_CD_2', 'CRM_CD_3', 'CRM_CD_4', 'LOCATION', 'CROSS_STREET', 'LAT', 'LON', 'YEAR', 'Month']

# %%
# Step 1: Clean column names - remove extra spaces and standardize case
df.columns = df.columns.str.strip().str.upper()

# Step 2: Check the actual column names
print(df.columns.tolist())  # This helps you find the correct column name

# Step 3: Use the actual column name based on the print output
# For example, if the column is actually 'DATE_OCC':
df['DATE_OCC'] = pd.to_datetime(df['DATE_OCC'], errors='coerce')
df['YEAR'] = df['DATE_OCC'].dt.year
# Out:
# ['DR_NO', 'DATE_RPTD', 'DATE_OCC', 'TIME_OCC', 'AREA', 'AREA_NAME', 'RPT_DIST_NO', 'PART_1-2', 'CRM_CD', 'CRM_CD_DESC', 'MOCODES', 'VICT_AGE', 'VICT_SEX', 'VICT_DESCENT', 'PREMIS_CD', 'PREMIS_DESC', 'WEAPON_USED_CD', 'WEAPON_DESC', 'STATUS', 'STATUS_DESC', 'CRM_CD_1', 'CRM_CD_2', 'CRM_CD_3', 'CRM_CD_4', 'LOCATION', 'CROSS_STREET', 'LAT', 'LON', 'YEAR', 'MONTH']

# %%
(D)

# %%
#Victim Demographics (Age, Gender, Descent)
#a. Victim Age Distribution:
plt.figure(figsize=(10, 5))
sns.histplot(df['VICT_AGE'], bins=30, kde=True, color="steelblue")
plt.title("Distribution of Victim Ages")
plt.xlabel("Age")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
#b. Victim Gender Count:
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

sns.countplot(data=df, x='VICT_SEX', hue='VICT_SEX', palette="pastel", legend=False)

plt.title("Victim Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
#c. Victim Descent:
df['VICT_DESCENT'].value_counts().head(10).plot(kind='bar', color='orchid')
plt.title("Top 10 Victim Descent Categories")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#4. Weapon Usage Trends
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Get top 10 weapon types
top_weapons = df['WEAPON_DESC'].value_counts().head(10).reset_index()
top_weapons.columns = ['Weapon', 'Count']

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(data=top_weapons, x='Weapon', y='Count', hue='Weapon', palette='magma', legend=False)

plt.title("Top 10 Weapons Used in Crimes")
plt.ylabel("Number of Incidents")
plt.xlabel("Weapon Type")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#5. Crimes by Day/Month
#a. Extracting Month:
# First, strip any leading/trailing whitespace from column names
df.columns = df.columns.str.strip()

# Print columns to confirm actual names
print(df.columns)

# Parse the correct datetime column (assuming it's named 'DATE OCC' originally)
df['DATE_OCC'] = pd.to_datetime(df['DATE_OCC'], errors='coerce')

# Extract the month correctly from the new 'DATE_OCC' column
df['Month'] = df['DATE_OCC'].dt.month
# Out:
# Index(['DR_NO', 'DATE_RPTD', 'DATE_OCC', 'TIME_OCC', 'AREA', 'AREA_NAME',
#        'RPT_DIST_NO', 'PART_1-2', 'CRM_CD', 'CRM_CD_DESC', 'MOCODES',
#        'VICT_AGE', 'VICT_SEX', 'VICT_DESCENT', 'PREMIS_CD', 'PREMIS_DESC',
#        'WEAPON_USED_CD', 'WEAPON_DESC', 'STATUS', 'STATUS_DESC', 'CRM_CD_1',
#        'CRM_CD_2', 'CRM_CD_3', 'CRM_CD_4', 'LOCATION', 'CROSS_STREET', 'LAT',
#        'LON', 'YEAR', 'MONTH', 'Month'],
#       dtype='object')

# %%
#PLOT
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='Month', hue='Month', palette='coolwarm', legend=False)
plt.title("Crimes per Month")
plt.xlabel("Month")
plt.ylabel("Crime Count")
plt.tight_layout()
plt.show()
